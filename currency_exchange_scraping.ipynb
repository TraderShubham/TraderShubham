# %%
import pandas as pd
table1 = pd.read_html('https://www.x-rates.com/table/?from=INR&amount=1')[0]
table1
# Out:
#             Indian Rupee  1.00 INR  inv. 1.00 INR
# 0              US Dollar  0.012183      82.081997
# 1                   Euro  0.010928      91.509359
# 2          British Pound  0.009363     106.805076
# 3      Australian Dollar  0.017831      56.083530
# 4        Canadian Dollar  0.016035      62.363940
# 5       Singapore Dollar  0.016176      61.818323
# 6            Swiss Franc  0.010520      95.056132
# 7      Malaysian Ringgit  0.056131      17.815531
# 8           Japanese Yen  1.686663       0.592887
# 9  Chinese Yuan Renminbi  0.087316      11.452711

# %%
table2 = pd.read_html('https://www.x-rates.com/table/?from=INR&amount=1')[1]
table2
# Out:
#              Indian Rupee      1.00 INR  inv. 1.00 INR
# 0          Argentine Peso      3.216279       0.310918
# 1       Australian Dollar      0.017831      56.083530
# 2          Bahraini Dinar      0.004581     218.303183
# 3           Botswana Pula      0.160464       6.231937
# 4          Brazilian Real      0.058713      17.031894
# 5         Bruneian Dollar      0.016176      61.818323
# 6           Bulgarian Lev      0.021373      46.787992
# 7         Canadian Dollar      0.016035      62.363940
# 8            Chilean Peso      9.887949       0.101133
# 9   Chinese Yuan Renminbi      0.087316      11.452711
# 10         Colombian Peso     50.359634       0.019857
# 11           Czech Koruna      0.259907       3.847529
# 12           Danish Krone      0.081443      12.278549
# 13                   Euro      0.010928      91.509359
# 14       Hong Kong Dollar      0.095294      10.493871
# 15       Hungarian Forint      4.106918       0.243492
# ...

# %%
final = pd.concat([table1, table2])
final
# Out:
#           Indian Rupee      1.00 INR  inv. 1.00 INR
# 0            US Dollar      0.012183      82.081997
# 1                 Euro      0.010928      91.509359
# 2        British Pound      0.009363     106.805076
# 3    Australian Dollar      0.017831      56.083530
# 4      Canadian Dollar      0.016035      62.363940
# ..                 ...           ...            ...
# 47        Turkish Lira      0.318694       3.137802
# 48      Emirati Dirham      0.044742      22.350442
# 49       British Pound      0.009363     106.805076
# 50           US Dollar      0.012183      82.081997
# 51  Venezuelan Bolivar  34495.137678       0.000029
#
# [62 rows x 3 columns]

# %%
data_to_csv = final.to_csv('INR_Conversion_Rates.csv', index=False)
