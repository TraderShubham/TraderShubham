# %%
import pandas as pd
table = pd.read_html('https://www.timeanddate.com/weather/india/new-delhi/ext')
len(table)
# Out:
# 1

# %%
table[0]
# Out:
#                                    Unnamed: 0_level_0  \
#                                                   Day
# 0                                       गुरु 13 जुलाई
# 1                                      शुक्र 14 जुलाई
# 2                                        शनि 15 जुलाई
# 3                                        रवि 16 जुलाई
# 4                                        सोम 17 जुलाई
# 5                                       मंगल 18 जुलाई
# 6                                        बुध 19 जुलाई
# 7                                       गुरु 20 जुलाई
# 8                                      शुक्र 21 जुलाई
# 9                                        शनि 22 जुलाई
# 10                                       रवि 23 जुलाई
# 11                                       सोम 24 जुलाई
# 12                                      मंगल 25 जुलाई
# 13                                       बुध 26 जुलाई
# 14                                      गुरु 27 जुलाई
# ...

# %%
table = pd.read_html('https://www.timeanddate.com/weather/india/new-delhi/ext')[0]
table.head()

# table.to_csv('weather_data.csv', index=False)
# Out:
#   Unnamed: 0_level_0         Conditions              \
#                  Day Unnamed: 1_level_1 Temperature
# 0      गुरु 13 जुलाई                NaN  30 / 27 °C
# 1     शुक्र 14 जुलाई                NaN  32 / 27 °C
# 2       शनि 15 जुलाई                NaN  30 / 27 °C
# 3       रवि 16 जुलाई                NaN  32 / 26 °C
# 4       सोम 17 जुलाई                NaN  31 / 28 °C
#
#                                          Comfort                              \
#                               Weather Feels Like     Wind Unnamed: 6_level_1
# 0  Passing showers. Afternoon clouds.      38 °C  14 km/h                  ↑
# 1     Passing showers. Mostly cloudy.      40 °C   7 km/h                  ↑
# 2            Thunderstorms. Overcast.      38 °C  13 km/h                  ↑
# 3             Rain showers. Overcast.      40 °C  10 km/h                  ↑
# 4          Passing showers. Overcast.      41 °C   2 km/h                  ↑
#
#            Precipitation                    Sun
# ...

# %%
# selecting the necessary columns 
data = ['Day', 'Temperature', 'Weather', 'Feels Like', 'Wind', 'Humidity', 'Chance', 'Amount', 'UV', 'Sunrise',	'Sunset']
final = table[data]
final

# %%
# dir(table)

# %%
import pandas as pd

# Read the HTML table into a DataFrame
table = pd.read_html('https://www.timeanddate.com/weather/india/new-delhi/ext')[0]

# List the columns you want to remove
columns_to_remove = ['Unnamed: 1_level_1', 'Unnamed: 6_level_1']

# Drop the specified columns from the DataFrame
table = table.drop(columns_to_remove, axis=1)
table

# Save the modified DataFrame as a CSV file
# table.to_csv('output.csv', index=False)
