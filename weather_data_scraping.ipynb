# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}
web = requests.get('https://www.timeanddate.com/weather/india/new-delhi/ext').text

# %%
soup = BeautifulSoup(web, 'lxml')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <!--
# scripts and programs that download content transparent to the user are not allowed without permission
# --><html lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>New Delhi, Delhi, India 14 day weather forecast</title><meta content="Forecasted weather conditions the coming 2 weeks for New Delhi" name="description"/><meta content="max-image-preview:large" name="robots"/><meta content="https://www.timeanddate.com/scripts/cityog.php?title=14-Day%20Weather%20Forecast%20for&amp;tint=0x007b7a&amp;city=New%20Delhi&amp;state=Delhi&amp;country=India&amp;image=new-delhi1" property="og:image"/><meta content="1366" property="og:image:width"/><meta content="768" property="og:image:height"/><meta content="website" property="og:type"/><style>
# ...

# %%
# title of the data
soup.find_all('h2')[1].text
# Out:
# '2 Week Extended Forecast in New Delhi, Delhi, India'

# %%
weather = soup.find_all('th')

# %%
weather = soup.find_all('tr')
Day=[]
for i in weather:
   Day.append(i.find('th'))
Day
# Out:
# [<th> </th>,
#  <th>Day</th>,
#  <th><span class="smaller soft">बुध</span><br/>12 जुलाई</th>,
#  <th><span class="smaller soft">गुरु</span><br/>13 जुलाई</th>,
#  <th><span class="smaller soft">शुक्र</span><br/>14 जुलाई</th>,
#  <th><span class="smaller soft">शनि</span><br/>15 जुलाई</th>,
#  <th><span class="smaller soft">रवि</span><br/>16 जुलाई</th>,
#  <th><span class="smaller soft">सोम</span><br/>17 जुलाई</th>,
#  <th><span class="smaller soft">मंगल</span><br/>18 जुलाई</th>,
#  <th><span class="smaller soft">बुध</span><br/>19 जुलाई</th>,
#  <th><span class="smaller soft">गुरु</span><br/>20 जुलाई</th>,
#  <th><span class="smaller soft">शुक्र</span><br/>21 जुलाई</th>,
#  <th><span class="smaller soft">शनि</span><br/>22 जुलाई</th>,
#  <th><span class="smaller soft">रवि</span><br/>23 जुलाई</th>,
#  <th><span class="smaller soft">सोम</span><br/>24 जुलाई</th>,
#  <th><span class="smaller soft">मंगल</span><br/>25 जुलाई</th>,
#  <th><span class="smaller soft">बुध</span><br/>26 जुलाई</th>,
# ...

# %%
for i in soup.find_all('tr'):
    print(i.text.strip())
# Out:
# ConditionsComfortPrecipitationSun
# Day TemperatureWeatherFeels LikeWind HumidityChanceAmountUVSunriseSunset
# बुध12 जुलाई32 / 27 °CThundershowers. Afternoon clouds.40 °C11 km/h↑72%77%5.4  mm5 (Moderate)05.3119.21
# गुरु13 जुलाई32 / 28 °CPassing showers. Afternoon clouds.39 °C11 km/h↑69%55%1.2  mm7 (High)05.3219.21
# शुक्र14 जुलाई32 / 27 °CIsolated tstorms. Overcast.40 °C15 km/h↑72%67%8.2  mm5 (Moderate)05.3219.21
# शनि15 जुलाई28 / 27 °CPassing showers. Overcast.34 °C18 km/h↑92%68%14.4  mm3 (Moderate)05.3319.20
# रवि16 जुलाई31 / 26 °CPassing showers. Cloudy.39 °C14 km/h↑73%66%7.0  mm7 (High)05.3319.20
# सोम17 जुलाई34 / 29 °CShowers late. Overcast.43 °C9 km/h↑60%39%0.7  mm5 (Moderate)05.3419.20
# मंगल18 जुलाई34 / 27 °CThunderstorms. Overcast.39 °C12 km/h↑83%55%6.8  mm5 (Moderate)05.3419.19
# बुध19 जुलाई32 / 26 °CThunderstorms. Overcast.38 °C10 km/h↑84%90%13.3  mm5 (Moderate)05.3519.19
# गुरु20 जुलाई32 / 27 °CTstorms early. Broken clouds.33 °C16 km/h↑45%99%12.8  mm7 (High)05.3519.19
# ...

# %%
Day = []
Temperature = []
Weather = []
FeelsLike = []
Wind = []
Humidity = []
Chance = []
Amount = []
UV = []
Sunrise = []
Sunset = []

# %%
soup.find_all('th')[5].text
# Out:
# 'Day'

# %%
final = pd.DataFrame()
for i in weather:
    Day.append(i.find('th'))
    Temperature.append(i.find('th')) 
    weather.append(i.find('th'))
    # FeelsLike.append(i.find('th').text.strip())
    # Wind.append(i.find('th').text.strip())
    # Humidity.append(i.find('th').text.strip())
    # Chance.append(i.find('th').text.strip())

    # # if len(Amount)>=4:
    # #     Amount.append(i.find('th').text.strip())
    # # else:
    # #     Amount.append(np.nan)   
    # try:
    #     Amount.append(i.find('th').text.strip())
    # except:
    #     Amount.append(np.nan)

    # UV.append(i.find('th').text.strip())
    # Sunrise.append(i.find('th').text.strip())
    # Sunset.append(i.find('th').text.strip())
    
d = {'Day':Day, 'Temperature':Temperature, 'Weather':Weather, 'FeelsLike':FeelsLike,'Wind':Wind, 'Humidity':Humidity, 'Chance':Chance, 'Amount':Amount, 'UV':UV, 'Sunrise':Sunrise, 'Sunset':Sunset}
df = pd.DataFrame(d)
final = final.append(df, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 3
#       1 final = pd.DataFrame()
#       2 for i in weather:
# ----> 3     Day.append(i.find('th'))
#       4     Temperature.append(i.find('th'))
#       5     weather.append(i.find('th'))
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
Day=[]
for i in weather:
    Day.append(i.find('th'))
Day

# %%
Day
